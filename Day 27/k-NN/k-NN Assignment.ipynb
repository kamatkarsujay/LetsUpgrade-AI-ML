# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import neighbors
from sklearn.metrics import *

# %%
df = pd.read_csv('train.csv')
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df = df.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)

# %%
le = preprocessing.LabelEncoder()

# %%
df['Sex'] = le.fit_transform(df['Sex'])

# %%
df['Embarked'] = le.fit_transform(df['Embarked'])

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  889 non-null    int64
#  1   Pclass    889 non-null    int64
#  2   Sex       889 non-null    int32
#  3   Age       889 non-null    float64
#  4   SibSp     889 non-null    int64
#  5   Parch     889 non-null    int64
#  6   Fare      889 non-null    float64
#  7   Embarked  889 non-null    int32
# dtypes: float64(2), int32(2), int64(4)
# memory usage: 48.7 KB

# %%
def k_NN(n,X,y):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)
    knn = neighbors.KNeighborsClassifier(n_neighbors=n)
    knn_score = knn.fit(X_train,y_train).score(X_test,y_test)
    y_pred = knn.predict(X_test)
    cm = confusion_matrix(y_test,y_pred)
#     if knn_score > 0.80:
    print('Accuracy Score for k={} is: {}'.format(i,knn_score))
    print('Confusion Matrix for k={} is: \n {}'.format(i,cm))

# %% [markdown]
# ### Accuracy Score and Confusion Matrix for Survived

# %%
X1 = df.drop(['Pclass'],axis=1)
y1 = df['Pclass']
for i in range(1,277):
    print('---------------------------------------')
    k_NN(i,X1,y1)
    print('---------------------------------------')
# Out:
# ---------------------------------------
# Accuracy Score for k=1 is: 0.8913857677902621
# Confusion Matrix for k=1 is:
#  [[ 62   6   2]
#  [  3  37   9]
#  [  1   8 139]]
# ---------------------------------------
# ---------------------------------------
# Accuracy Score for k=2 is: 0.8651685393258427
# Confusion Matrix for k=2 is:
#  [[ 67   2   1]
#  [  8  37   4]
#  [  4  17 127]]
# ---------------------------------------
# ---------------------------------------
# Accuracy Score for k=3 is: 0.8651685393258427
# Confusion Matrix for k=3 is:
#  [[ 63   5   2]
#  [  7  28  14]
#  [  3   5 140]]
# ---------------------------------------
# ---------------------------------------
# Accuracy Score for k=4 is: 0.8239700374531835
# Confusion Matrix for k=4 is:
#  [[ 61   7   2]
#  [  8  30  11]
#  [  4  15 129]]
# ---------------------------------------
# ---------------------------------------
# Accuracy Score for k=5 is: 0.8314606741573034
# Confusion Matrix for k=5 is:
# ...
